# %% [markdown]
# ## 用laZagne.exe all 可以读取本地的所有密码
# 支持读取下面软件的密码,思路是读取后网上用md5网站破解试试,如果不行用下面的kail的psexec工具以及彩虹表破解
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 利用彩虹表破解
#
# Ophcrack是一款利用彩虹表来破解的软件,不过缺点是这个软件很大,几十个G的容量.但是对于加盐的hash值 基本无效了

# %% [markdown]
# ## 使用kali的psexec工具,不过新版本似乎实验失败,需要用老的2.0版本
# 用MSF里的psexec工具去获取其他主机的密码hash值
# ```use exploit/windows/smb/psexec```
# 设置Rhosts,Rport因为是用SMB破解,默认端口就是445,把用laZagne.exe读取的账号和密码hash值写入进去
# 下面是windows2003读取出来的管理员密码hash值
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
# 然后进行run 破解
