# %% [markdown]
# ## 旁注:在同一服务器上有多个站点，我们要攻击的这个站点假设没有漏洞，我们可以攻击服务器上的任意一个站点，这个就是旁注

# %% [markdown]
# 旁注攻击的原理就是中间件部署网站的时候的权限是跟随当前账户的权限走的.而一旦使用管理员账号进行安装中间件,那么中间件也是管理员权限,一旦旁注入侵,因为网站都开启了匿名访问,而所有的匿名访问用的都是iuser的账号.因此一个网站被入侵后,那么iuser账号因为同样的权限,自然可以访问并对其他网站文件进行改查权限.
# 解决旁注:新建多个普通权限的用户,用户隶属于guest组,并且每个普通账户设不同密码
# ![image-2.png](attachment:image-2.png)
# 网站权限中把之前的user用户删除,添加新增的普通用户
# ![image-3.png](attachment:image-3.png)
# 把匿名访问用户改成新增的用户
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## CDN判断
#
# 1. cmd中启用nslookup,如果启用了CDN,可以看下图访问百度和宁波港EDI中间的区别,有CDN的会有别名出现
# ![image-2.png](attachment:image-2.png)
# 2. 用ping也可以看出CDN的网站后面有别名
# ![image-3.png](attachment:image-3.png)
# 3. 通过第三方网站ping结果判断是否启用CDN.如果未使用CDN,那么响应的IP应该就一个,如果有很多不同的多个ip就是CDN,这和CDN的原理有关.
#     - 通过站长之家等网站查询 http://ping.chinaz.com
#     - ping.cn https://www.ping.cn/
#     - 17ce https://www.17ce.com/
#
# ```备注一个小知识  可以用tracert + www.baidu.com 可以看数据包从每个设备的走向(不是用来判断CDN的)```
# ![image-4.png](attachment:image-4.png)
#
#
# ## CDN绕过
# 1. 用fofa等网站查询
# 2. 如果开启了泛域名查询,可以ping一个不存在的二级域名
# 3. 通过DNS历史记录网站或者微步在线等情报网站
#     - https://dnsdb.io/zh-cn/ ###DNS查询
#     - https://x.threatbook.cn/ ###微步在线
#     - http://toolbar.netcraft.com/site_report?url= ###可以看到ip变化 比较好用
#     - http://viewdns.info/ ###DNS、IP等查询
#     - https://tools.ipip.net/cdn.php ###CDN查询IP
#     - https://securitytrails.com/domain/oldboyedu.com/dns
# 4. 通过SSL证书查找
# 5. 通过国外服务器ping对方网站,因为国外没有做CDN
# 6. 对方网站漏洞查找(比较有难度)
#     - 目标敏感文件泄露，例如：phpinfo之类的探针、"info.php", "phpinfo.php", "test.php", "l.php"、GitHub信息泄露等。
#     - 查看漏洞扫描报警信息，手工造成页面报错
#     - XSS盲打，命令执行反弹shell，SSRF等。
#     - 无论是用社工还是其他手段，拿到了目标网站管理员在CDN的账号，从而在从CDN的配置中找到网站的真实IP。
# 7. 查找子域名,因为不可能所有域名都用CDN服务,虽然可能在不同的服务器
# 8. 网站邮件订阅查找,如下图所示
# ![image-5.png](attachment:image-5.png)
# 9. 用 Zmap扫全网、DDOS把 CDN 流量打光,因为CDN要花钱买流量,DDOS打光流量就会被运营商停掉

# %% [markdown]
# # 目录越权
# 由于运维人员安装中间件时候登陆的账号就是管理员或者root权限,导致中间件权限过高.容易造成目录越权

# %% [markdown]
# ## 跨库查询
# 指由于权限设置不严格，导致普通帐号被授予过高的权限，从而使得其可以对其他的数据库进行操作。比如，在mysql中，informatin_schema
# 这个表默认只有root有权限进行操作。但是如果一个普通账户权限过高后，他便可以对该数据库进行操作，从而影响整个mysql数据库的运行。
