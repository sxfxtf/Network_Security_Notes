# %% [markdown]
# # 任意文件下载
# 下面的利用点都可以考虑使用../进行测试看是否可以随意切换路径
#
# 一般链接形式:
# download.php?path=
# down.php?file=
# data.php?file=
# download.php?filename=
#
# 或者包含参数:
# &Src=
# &Inputfile=
# &Filepath=
# &Path=
# &Data=
#
# ## 绕过思路
# 如果网站后台只是简单的过滤../,那么我们可以构造..././ ,替换后还是一个../
#
# ## 攻击思路
#
# - 下载常规的配置文件，例如: ssh,weblogic,ftp,mysql等相关配置
# - 下载各种.log文件，从中寻找一些后台地址，文件上传点之类的地方，如果运气好的话会获得一些前辈们的后门。
# - 下载web业务文件进行白盒审计，利用漏洞进一步攻入服务器,尝试读取/root/.bash_history看自己是否具有root权限。
# 如果没有的话。我们只能按部就班的利用../来回跳转读取一些.ssh下的配置信息文件，读取mysql下的.bash_history文件。来查看是否记录了一些可以利用的相关信息。然后逐个下载我们需要审计的代码文件，但是下载的时候变得很繁琐，我们只能尝试去猜解目录，然后下载一些中间件的记录日志进行分析。
# - 如果我们遇到的是java+oracle环境
# 可以先下载/WEB-INF/classes/applicationContext.xml 文件，这里面记载的是web服务器的相应配置，然后下载/WEB-INF/classes/xxx/xxx/ccc.class对文件进行反编译，然后搜索文件中的upload关键字看是否存在一些api接口，如果存在的话我们可以本地构造上传页面用api接口将我们的文件传输进服务器
# - 如果具有root权限
# 在linux中有这样一个命令 locate 是用来查找文件或目录的，它不搜索具体目录，而是搜索一个数据库/var/lib/mlocate/mlocate.db。这个数据库中含有本地所有文件信息。Linux系统自动创建这个数据库，并且每天自动更新一次。当我们不知道路径是什么的情况下，这个可以说是一个核武器了，我们利用任意文件下载漏洞mlocate.db文件下载下来，利用locate命令将数据输出成文件，这里面包含了全部的文件路径信息。
#
# ## 防御思路
# （1）过滤"."，使用户在url中不能回溯上级目录
# （2）正则严格判断用户输入参数的格式
# （3）php.ini配置open_basedir限定下载文件范围,规定所有的下载路径,这样也能防御

# %% [markdown]
# # 任意文件上传

# %% [markdown]
# # 总结
# ![image.png](attachment:image.png)
# 下面具体举例了图中的几种CTF考题中文件上传绕过的思路
# 1. 一般生产环境中我们先判断是客户端检查还是服务端检查.用BP修改递交数值,如果直接改后缀能成功欺骗,表示是客户端检查.
# 2. 检查黑名单还是白名单策略,如果随意上传一个图片,文件名会被重命名,基本黑名单绕过不太可能.
# 3. 白名单绕过,除了MIME绕过外,其他的00截断成功的前提条件是apache的版本不能高于5.4,且魔术字符需要关闭
# 4. 检查内容这块内容,要运行木马还是要依赖于文件包含漏洞来运行木马.
# 5. 条件竞争就是最后11和12的时间竞争,通过返回包确认木马上传路径.

# %% [markdown]
# 1. 客户端检测绕过(javascript 检测)
#  首先观察到提示只允许上传图片文件，那么前端的查看代码，当页面发生改变时，会调用这个checkFileExt函数来检查上传文件后缀.如果只是单纯前端校验的话,那么我们可以先欺骗前端,再通过抓包修改上传文件后缀进行绕过
#  php的代码截图
#  ![image-9.png](attachment:image-9.png)
#  分析截图
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# 这个例子在pikachu的 unsafe upfileupload模块.正常是会判断后缀的.
# 我们接下来试试抓包绕过,我们先选一个jpg的文件上传
# ![image-3.png](attachment:image-3.png)
# 再修改包里的数据,进行上传
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# 2. 服务端验证绕过(MIME 类型检测)
#       MIME(Multipurpose Internet Mail Extensions)多用途互联网邮件扩展类型。是设定某种扩展名的文件用一种应用程序来打开的方式类型，当该扩展名文件被访问的时候，浏览器会自动使用指定应用程序来打开。多用于指定一些客户端自定义的文件名，以及一些媒体文件打开方式。
# 每个MIME类型由两部分组成，前面是数据的大类别，例如声音audio、图象image等，后面定义具体的种类。
# 由于设定了文件类型为任意二进制数据,因此会拒绝打开jsp等后缀的执行文件. 我们还是可以通过抓包更改文件类型进行绕过,这里我们改成的是image/png
# php的代码截图
# ![image-8.png](attachment:image-8.png)
#
# 分析截图
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# '''
# 常见的MIME类型(通用型)：
# 超文本标记语言文本 .html text/html
# xml文档 .xml text/xml
# XHTML文档 .xhtml application/xhtml+xml
# 普通文本 .txt text/plain
# RTF文本 .rtf application/rtf
# PDF文档 .pdf application/pdf
# Microsoft Word文件 .word application/msword
# PNG图像 .png image/png
# GIF图形 .gif image/gif
# JPEG图形 .jpeg,.jpg image/jpeg
# au声音文件 .au audio/basic
# MIDI音乐文件 mid,.midi audio/midi,audio/x-midi
# RealAudio音乐文件 .ra, .ram audio/x-pn-realaudio
# MPEG文件 .mpg,.mpeg video/mpeg
# AVI文件 .avi video/x-msvideo
# GZIP文件 .gz application/x-gzip
# TAR文件 .tar application/x-tar
# 任意的二进制数据 application/octet-stream
# '''
#
# 3. 代码限制了asp,aspx,php,jsp后缀,如果服务器配置了不限制php3 php5等后缀名,可以尝试上传php3后缀的
# php的代码截图
# ![image-10.png](attachment:image-10.png)
# 这种方式前提条件是运维人员允许php3等这样的后缀名

# %% [markdown]
# 4. 将php3等后缀也加入黑名单 但是没有限制.htaccess文件的上传，所以我们依然可以使用,
# 另一种方法:利用PHP 和 Windows环境的叠加特性，以下符号在正则匹配时的相等性:
#  利用PHP 和 Windows环境的叠加特性，以下符号在正则匹配时的相等性：
# 双引号"     =   点号.
# 大于符号>   =   问号?
# 小于符号<   =   星号*
# 先上传一个名为4.php:.jpg的文件，上传成功后会生成4.php的空文件，大小为0KB.
# 然后将文件名改为4.<或4.<<<或4.>>>或4.>><后再次上传，重写4.php文件内容，Webshell代码就会写入原来的4.php空文件中。
# php代码截图
# ![image.png](attachment:image.png)
#
# 我们直接BP抓包改后缀,讲上传的Php.php改成php.:.jpg通过Php检测
# ![image-3.png](attachment:image-3.png)
# 此时文件大小为0kb,需要再次抓包改后缀把后面内容跟进来
# ![image-4.png](attachment:image-4.png)
# 把后缀改成Php.<
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 5. Linux区分大小写,windows默认会文件名去除两边空格.
# 所以可以抓包改后缀名的大小写.PhP  或者后缀添加空格 .php  .,windows会自动忽略空格后的内容  或者php.php. 加入点和空格.windows也会忽略
# 还可以利用上面php.php.的特性可以复写比如Php.php. .可以让在替换 .后 复原成php.php.,再利用windos去除最后的.
# 还可以后缀改.phphpp.
# 6. 利用windows文件流特性
# ```改文件后缀为php::$DATA.
# php在window的时候如果文件名+"::$DATA"会把::$DATA之后的数据当成文件流处理,不会检测后缀名.且保持"::$DATA"之前的文件名```

# %% [markdown]
# 7. 有些网站后缀名设定为白名单模式,只有固定的后缀文件才能上传,此时在后缀上做文章不太可行.
# 我们考虑从路径上用00截断进行绕过.这个漏洞php版本要小于5.3.4，5.3.4及以上已经修复该问题；magic_quotes_gpc需要为OFF状态(考题)
# ![image.png](attachment:image.png)
# 上图的原理为,我们构造了一个路径../upload/fuck.php%00/fuck.jpg, 这个路径符合后缀为jpg的要求,但是实际执行时候,%00会截断后面的/fuck.jpg,从而路径变成了../upload/fuck.php

# %% [markdown]
# 8. 当POST的路径没有在URI理,而是在参数中,我们构造00截断方法又有所不同.
# 主要的思路是在路径后添加php文件,后面跟一个空格,file改成正常允许上传的文件.
# ![image.png](attachment:image.png)
# 在16进制里,空格是0x20,我们把这个20改成00,让他进行截断后面的字符内容
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 9. 文件都有文件头,比如gif文件就有GIF89a头
# ![image-2.png](attachment:image-2.png)
# 或者我们使用命令copy 1.jpg /b + shell.php /a webshell.jpg，将php一句话追加到jpg图片末尾，代码不全的话，人工补充完整。形成一个包含Webshell代码的新jpg图片，然后直接上传即可。但是我们没有办法拿到shell，应为我们上传的图片马无法被解析成php形式，通常图片马配合%00或者0x00截断上传，或者配合解析漏洞

# %% [markdown]
# 10. 二次渲染,图片可以用工具生成一句话木马并且包含在图片中,路径:漏洞利用\edjpgcom图片插入一句话工具
# 但是现在上传后,服务器程序会进行二次渲染,过滤里面的一句话木马
# 下面是针对二次渲染的解决文章,原理是生成很多图片,每个图片不同位置都插入一句话木马,上传后看哪个坚强的小马可以存活下来
# php图像二次渲染：
# https://blog.csdn.net/hitwangpeng/article/details/48661433
# https://blog.csdn.net/hitwangpeng/article/details/46548849
# https://xz.aliyun.com/t/2657
# 这两个讲的还可以

# %% [markdown]
# 11. 时间竞争
#
# 原理:上传小马(假设文件名为tp.php),里面的代码功能是一旦双击访问,便在其文件路径下额外生成一个qing.php的文件,qing.php这个文件写入了一句木马.
# 利用BP或者其他软件,开启多线程批量上传,由于文件不符合后缀名要求,所以上传服务器后会被删除,
# 但是上传-判断-删除中间一定有延迟,利用这个延迟再开另一个脚本不断访问该路径下的tp.php.一旦tp.php在删除前被访问,则会生成qing.php小马.
# 准备木马
# ```<?php
# $myfile = fopen("qing.php", "w");
# $txt = "<?php @eval($_POST['123']);?>";
# fwrite($myfile, $txt);
# fclose($myfile);
# ?>```
#
# Burp suite设置如下
# 清除变量,因为不需要字典暴力,因此无需动态向参数写入数值
# ![image.png](attachment:image.png)
# 因为不需要爆破,挂载字典,所以选择没有负载,并根据实际情况选择无限循环或者指定循环次数
# ![image-2.png](attachment:image-2.png)
# 设定线程数,加速上传速度
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 12. 时间竞争和APACHE解析漏洞
# 时间竞争看上面11的例子,APACHE中间件的解析漏洞,比如上传一个文档show_php.php.7z,APACHE是从右往左解析,由于.7z后缀不认识,会自动忽略并往前按照PHP解析.在pass-18例子里,上传文件会被重命名,并按最后一个后缀命名后缀名,比如改成201546.7z,但是由于快速上传,计算机有概率会丢失几个文件没有按规按最后一个后缀命名,也就是说上传后,还是有少部分文件除了修改文件名以外,后缀还是.php.7z.这个时候利用apache解析漏洞就可以按php解析了.
# ![image.png](attachment:image.png)

# %% [markdown]
# 13. 在知晓源代码的前提下,可以根据代码的漏洞进行绕过
# 代码如下,也是限定了上传白名单,只能接受jpg png gif
# ![image.png](attachment:image.png)
# 利用BP修改参数如下,save_name这个参数的索引save_name[0]为tj.php save_name[1]为jpg,save_name一共就2个索引,所以save_name[3]为空,没有数据.所以代码的字符串拼凑就是tj.php,但是post的包数据把Content-Type改了 image/jpeg,并且后缀为jpg.所以可以绕过检测,但是实际上传到服务器的还是tj.php
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 文件上传防御
# 1. 对上传的文件进行重命名,设置上传后缀的白名单.
# 2. 对上传文件进行二次渲染,过滤里面的木马代码
# 3. 设置上传指定目录,对该目录做禁止运行脚本权限,就算上传了木马也无法执行.
# 4. 更安全的做法就是设置签名和加密
