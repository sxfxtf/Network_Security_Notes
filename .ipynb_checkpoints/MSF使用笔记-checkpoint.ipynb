# %% [markdown]
# ## MSF 使用笔记  推荐学习网站```https://www.offensive-security.com/metasploit-unleashed/```
# use 略
#
# search 略
#
# show info 查看payload的具体介绍信息.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Msfvenom 模块
# - ## 用来生成payload的
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# - ## 比如生成一个混淆的木马
# 先用下-h参数,看下有哪些参数,-l是列出目录, encoder就是混淆的意思
# ![image-3.png](attachment:image-3.png)
# - ## 我们输入msfvenom -l encoder 这里面name是她的混淆类型
# ![image-4.png](attachment:image-4.png)
# - ## 第1步是没有混淆的,第二部是经过混淆的
# ![image-5.png](attachment:image-5.png)
#
# - ## 然后就是使用下面的multi/hander开启本地监听IP和端口 等对面反向连接后进入meterpreter界面
# - ## 然后再开始上传下载,截屏等对肉鸡的操作,常见的操作有如下:
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## 木马后门连接模块 /multi/hander
# ![image.png](attachment:image.png)
# 就是设置payload,然后选择本地监听的ip和端口.
# 运行,等木马反向连接即可

# %% [markdown]
# ## meterpreter 一般是和目标主机连接成功用来执行操作指令的模块
#
# 输入help可以查看到命令帮助
# 常用命令看下面博客内容.
# https://www.fujieace.com/metasploit/meterpreter-basics.html
